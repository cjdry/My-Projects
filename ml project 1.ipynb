# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import os, io
from pandas import Series, DataFrame, read_table
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn.preprocessing import LabelEncoder
data1=pd.read_csv('BX-Book-Ratings.csv')
data2=pd.read_csv('BX-Books.csv') 
print(data1.shape,data2.shape)
# Out:
# (1048575, 3) (271379, 5)

# %%
data1.head()
# Out:
#    user_id        isbn  rating
# 0   276725  034545104X       0
# 1   276726   155061224       5
# 2   276727   446520802       0
# 3   276729  052165615X       3
# 4   276729   521795028       6

# %%
data2.head()
# Out:
#         isbn                                         book_title  \
# 0  195153448                                Classical Mythology
# 1    2005018                                       Clara Callan
# 2   60973129                               Decision in Normandy
# 3  374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  393045218                             The Mummies of Urumchi
#
#             book_author year_of_publication                   publisher
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company

# %%
data1.dtypes
# Out:
# user_id     int64
# isbn       object
# rating      int64
# dtype: object

# %%
data2.dtypes
# Out:
# isbn                   object
# book_title             object
# book_author            object
# year_of_publication    object
# publisher              object
# dtype: object

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 3 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   user_id  1048575 non-null  int64
#  1   isbn     1048575 non-null  object
#  2   rating   1048575 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 24.0+ MB

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271379 entries, 0 to 271378
# Data columns (total 5 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   isbn                 271379 non-null  object
#  1   book_title           271379 non-null  object
#  2   book_author          271378 non-null  object
#  3   year_of_publication  271379 non-null  object
#  4   publisher            271377 non-null  object
# dtypes: object(5)
# memory usage: 10.4+ MB

# %%
data1.isna().sum()
# Out:
# user_id    0
# isbn       0
# rating     0
# dtype: int64

# %%
data2.isna().sum()
# Out:
# isbn                   0
# book_title             0
# book_author            1
# year_of_publication    0
# publisher              2
# dtype: int64

# %%
data2.dropna(inplace=True)

# %%
data2.isna().sum()
# Out:
# isbn                   0
# book_title             0
# book_author            0
# year_of_publication    0
# publisher              0
# dtype: int64

# %%
data1.columns
# Out:
# Index(['user_id', 'isbn', 'rating'], dtype='object')

# %%
data2.columns
# Out:
# Index(['isbn', 'book_title', 'book_author', 'year_of_publication',
#        'publisher'],
#       dtype='object')

# %%
for i in data1.columns:
    print("Number of unique values in {} \n The unique values are {}".format(i,len(data1[i].unique()),data1[i].unique()))
# Out:
# Number of unique values in user_id
#  The unique values are 95513
# Number of unique values in isbn
#  The unique values are 322102
# Number of unique values in rating
#  The unique values are 11

# %%
for i in data2.columns:
    print("Number of unique values in {} \n The unique values are {}".format(i,len(data2[i].unique()),data2[i].unique()))
# Out:
# Number of unique values in isbn
#  The unique values are 271376
# Number of unique values in book_title
#  The unique values are 242148
# Number of unique values in book_author
#  The unique values are 102041
# Number of unique values in year_of_publication
#  The unique values are 202
# Number of unique values in publisher
#  The unique values are 16822

# %%
n_f_c=list(data1._get_numeric_data().columns)
n_f_c
# Out:
# ['user_id', 'rating']

# %%
c_f_c=list(set(data1.columns)-set(data1._get_numeric_data().columns))
c_f_c
# Out:
# ['isbn']

# %%
n_f_c=list(data2._get_numeric_data().columns)
n_f_c
# Out:
# []

# %%
c_f_c=list(set(data2.columns)-set(data2._get_numeric_data().columns))
c_f_c
# Out:
# ['year_of_publication', 'isbn', 'book_title', 'publisher', 'book_author']

# %%
data1
# Out:
#          user_id        isbn  rating
# 0         276725  034545104X       0
# 1         276726   155061224       5
# 2         276727   446520802       0
# 3         276729  052165615X       3
# 4         276729   521795028       6
# ...          ...         ...     ...
# 1048570   250764   451410777       0
# 1048571   250764   452264464       8
# 1048572   250764  048623715X       0
# 1048573   250764   486256588       0
# 1048574   250764   515069434       0
#
# [1048575 rows x 3 columns]

# %%
le_isbn=LabelEncoder()
le_userid=LabelEncoder()
data1['isbn']=le_isbn.fit_transform(data1['isbn'])
data1['user_id']=le_userid.fit_transform(data1['user_id'])
data1
# Out:
#          user_id    isbn  rating
# 0          94663    4511       0
# 1          94664   30815       5
# 2          94665  158458       0
# 3          94666    9704       3
# 4          94666  177084       6
# ...          ...     ...     ...
# 1048570    94662  167557       0
# 1048571    94662  169219       8
# 1048572    94662    9215       0
# 1048573    94662  171876       0
# 1048574    94662  173457       0
#
# [1048575 rows x 3 columns]

# %%
new_data=pd.concat([data1],axis=1)
new_data.head()
# Out:
#    user_id    isbn  rating
# 0    94663    4511       0
# 1    94664   30815       5
# 2    94665  158458       0
# 3    94666    9704       3
# 4    94666  177084       6

# %%
le_isbn=LabelEncoder()
le_userid=LabelEncoder()
data2['isbn']=le_isbn.fit_transform(data2['isbn'])
data2
# Out:
#           isbn                                         book_title  \
# 0        57258                                Classical Mythology
# 1        57636                                       Clara Callan
# 2       177767                               Decision in Normandy
# 3       107193  Flu: The Story of the Great Influenza Pandemic...
# 4       119102                             The Mummies of Urumchi
# ...        ...                                                ...
# 271374  133898                         There's a Bat in Bunk Five
# 271375  157255                            From One to One Hundred
# 271376     327  Lily Dale : The True Story of the Town that Ta...
# 271377   55314                        Republic (World's Classics)
# 271378  216056  A Guided Tour of Rene Descartes' Meditations o...
#
#                  book_author year_of_publication  \
# 0         Mark P. O. Morford                2002
# 1       Richard Bruce Wright                2001
# ...

# %%
new_data1=pd.concat([data2],axis=1)
new_data1.head()
# Out:
#      isbn                                         book_title  \
# 0   57258                                Classical Mythology
# 1   57636                                       Clara Callan
# 2  177767                               Decision in Normandy
# 3  107193  Flu: The Story of the Great Influenza Pandemic...
# 4  119102                             The Mummies of Urumchi
#
#             book_author year_of_publication                   publisher
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company

# %%
c_data=pd.merge(new_data,new_data1,on='isbn')
c_data=c_data[['isbn','user_id','rating','book_title','book_author','year_of_publication','publisher']]

# %%
c_data.head()
# Out:
#    isbn  user_id  rating          book_title    book_author  \
# 0  4511    94663       0  Just The Fax Ma'Am  Leslic O'Kane
# 1  4511      805       5  Just The Fax Ma'Am  Leslic O'Kane
# 2  4511     2372       0  Just The Fax Ma'Am  Leslic O'Kane
# 3  4511     3159       5  Just The Fax Ma'Am  Leslic O'Kane
# 4  4511     3711       9  Just The Fax Ma'Am  Leslic O'Kane
#
#   year_of_publication          publisher
# 0                1997  Worldwide Library
# 1                1997  Worldwide Library
# 2                1997  Worldwide Library
# 3                1997  Worldwide Library
# 4                1997  Worldwide Library

# %%
new_data1.isbn.tolist()
# Out:
# [57258,
#  57636,
#  177767,
#  107193,
#  119102,
#  124680,
#  129016,
#  192727,
#  194574,
#  12787,
#  216885,
#  14354,
#  256860,
#  28218,
#  31390,
#  37206,
#  41157,
#  51972,
#  133539,
#  149041,
#  178012,
#  46940,
#  51546,
#  179489,
#  130349,
#  202082,
#  270366,
#  89280,
#  89534,
#  198312,
#  109649,
#  128577,
#  81499,
#  83913,
#  84017,
#  84395,
#  108221,
#  137256,
#  140998,
#  173616,
#  5456,
#  9115,
#  11292,
#  180016,
#  166291,
#  193229,
#  166281,
#  129260,
#  7005,
#  133252,
#  230372,
#  240960,
#  133352,
#  176419,
#  32680,
#  64171,
#  111826,
#  162951,
#  267616,
#  268491,
#  188692,
#  196739,
#  196997,
#  59938,
#  85328,
#  121835,
#  6824,
#  224527,
#  48180,
#  76085,
#  47994,
#  25341,
#  177064,
#  19578,
#  90564,
#  148652,
#  30987,
#  136514,
#  122690,
#  38635,
#  108308,
#  269270,
#  15772,
#  81989,
#  209065,
#  176844,
#  173886,
#  205343,
#  108881,
#  159031,
#  78204,
#  244426,
#  244433,
#  244434,
# ...

# %%
new_data.user_id.tolist()
# Out:
# [94663,
#  94664,
#  94665,
#  94666,
#  94666,
#  94667,
#  94668,
#  94669,
#  94670,
#  94671,
#  94672,
#  94672,
#  94672,
#  94672,
#  94672,
#  94672,
#  94673,
#  94673,
#  94673,
#  94673,
#  94673,
#  94673,
#  94673,
#  94673,
#  94674,
#  94674,
#  94675,
#  94675,
#  94676,
#  94677,
#  94678,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94679,
#  94680,
#  94681,
#  94682,
#  94682,
#  94682,
#  94682,
#  94682,
#  94683,
#  94683,
#  94683,
#  94683,
#  94683,
#  94684,
#  94684,
#  94684,
#  94685,
#  94685,
#  94685,
#  94685,
#  94685,
#  94685,
#  94685,
#  94685,
#  94685,
#  94685,
#  94685,
#  94685,
#  94686,
#  94686,
#  94686,
#  94687,
#  94687,
#  94688,
#  94688,
#  94688,
#  94688,
#  94688,
#  94688,
#  94688,
#  94688,
#  94688,
#  94688,
#  94688,
#  94688,
# ...

# %%
new_data.reset_index()
# Out:
#            index  user_id    isbn  rating
# 0              0    94663    4511       0
# 1              1    94664   30815       5
# 2              2    94665  158458       0
# 3              3    94666    9704       3
# 4              4    94666  177084       6
# ...          ...      ...     ...     ...
# 1048570  1048570    94662  167557       0
# 1048571  1048571    94662  169219       8
# 1048572  1048572    94662    9215       0
# 1048573  1048573    94662  171876       0
# 1048574  1048574    94662  173457       0
#
# [1048575 rows x 4 columns]

# %%
new_data.to_csv('new_data.csv')

# %%
new_data1.reset_index()
# Out:
#          index    isbn                                         book_title  \
# 0            0   57258                                Classical Mythology
# 1            1   57636                                       Clara Callan
# 2            2  177767                               Decision in Normandy
# 3            3  107193  Flu: The Story of the Great Influenza Pandemic...
# 4            4  119102                             The Mummies of Urumchi
# ...        ...     ...                                                ...
# 271371  271374  133898                         There's a Bat in Bunk Five
# 271372  271375  157255                            From One to One Hundred
# 271373  271376     327  Lily Dale : The True Story of the Town that Ta...
# 271374  271377   55314                        Republic (World's Classics)
# 271375  271378  216056  A Guided Tour of Rene Descartes' Meditations o...
#
#                  book_author year_of_publication  \
# ...

# %%
pip install surprise
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 22.0.3; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3.7 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from surprise import KNNBasic
from surprise import Dataset
from surprise import Reader
from surprise.model_selection import cross_validate
from surprise import accuracy
from surprise.model_selection import train_test_split


# path to dataset file
file_path = os.path.expanduser('new_data')

# As we're loading a custom dataset, we need to define a reader. In the
# movielens-100k dataset, each line has the following format:
# 'user item rating timestamp', separated by '\t' characters.
reader = Reader(line_format='user item rating', sep=',',skip_lines=1)

data = Dataset.load_from_file("new_data.csv", reader=reader)

# We can now use this dataset as we please, e.g. calling cross_validate
cross_validate(KNNBasic(), data, verbose=True)
# Out:
# Computing the msd similarity matrix...
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-33-23a64596ad3a> in <module>
#      19
#      20 # We can now use this dataset as we please, e.g. calling cross_validate
# ---> 21 cross_validate(KNNBasic(), data, verbose=True)
#
# /usr/local/lib/python3.7/site-packages/surprise/model_selection/validation.py in cross_validate(algo, data, measures, cv, return_train_measures, n_jobs, pre_dispatch, verbose)
#      99                                            return_train_measures)
#     100                     for (trainset, testset) in cv.split(data))
# --> 101     out = Parallel(n_jobs=n_jobs, pre_dispatch=pre_dispatch)(delayed_list)
#     102
#     103     (test_measures_dicts,
#
# /usr/local/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
# ...
